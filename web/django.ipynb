# %%
# !django-admin startproject soccer

# %%
# !python soccer/manage.py startapp matches

# %%
# !python -m django --version
# Out:
# 4.2.3

# %%
# !python soccer/manage.py collectstatic
# Out:
# 126 static files copied to '/var/www/example.com/static'.

# %%
import json
import gspread
import pandas as pd
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.3) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
gc = gspread.service_account(filename='Soccer.json')
sh = gc.open("Soccer")
worksheet = sh.worksheet('Soccer')
df = pd.DataFrame(worksheet.get_all_records())

# %%
df.head(10)
# Out:
#                    Data   GameId                     Time Local TipoMetrica  \
# 0   2023-08-23 18:43:00  1179285        Alianza Petrolera  Home     Current
# 1   2023-08-23 18:43:00  1179285        Alianza Petrolera  Home       H & A
# 2   2023-08-23 18:43:00  1179285               La Equidad  Away     Current
# 3   2023-08-23 18:43:00  1179285               La Equidad  Away       H & A
# 4   2023-08-23 19:00:00  1179624        Belgrano Reserves  Home     Current
# ..                  ...      ...                      ...   ...         ...
# 95  2023-08-23 21:00:00  1179161     Birmingham Legion FC  Away       H & A
# 96  2023-08-23 21:00:00  1179699       CS Herediano Women  Home     Current
# 97  2023-08-23 21:00:00  1179699       CS Herediano Women  Home       H & A
# 98  2023-08-23 21:00:00  1179699  Sporting San Jose Women  Away     Current
# 99  2023-08-23 21:00:00  1179699  Sporting San Jose Women  Away       H & A
#
# ...

# %%
import pandas as pd 
from datetime import datetime

pd.DataFrame({'Data': [datetime.now()]})
# Out:
#                         Data
# 0 2023-08-24 23:03:24.466414
